# %% [markdown]
# # Working with Titanic Dataset ( Data Visualization 2 )

# %% [markdown]
# Load Titanic dataset which is available in seaborn and answer the questions.

# %%
import pandas as pd
import numpy as np
import datetime as dt
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

titanic = sns.load_dataset('titanic')
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
titanic.shape
# Out:
# (891, 15)

# %%
titanic.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
titanic.isnull().any()
# Out:
# survived       False
# pclass         False
# sex            False
# age            False
# sibsp          False
# parch          False
# fare           False
# embarked       False
# class          False
# who            False
# adult_male     False
# deck           False
# embark_town    False
# alive          False
# alone          False
# dtype: bool

# %% [markdown]
# There are NaNs in age, embarked, deck and embark_town. Do remember to handle them when using those columns.

# %% [markdown]
# #### 1. Plot the age distribution of passangers using distplot(). Use dropna to drop rows with NaN values in column age.

# %%
titanic.dropna(inplace=True)
fig,ax =plt.subplots(figsize=(15,8))
sns.set()
sns.distplot(titanic['age'],ax=ax)

# %% [markdown]
# #### 2. Create an lmplot of age and fare. Use plt.ylim(0, 300) to exclude outliers

# %%
temp = pd.DataFrame()
temp['age'] = titanic['age']
temp['fare']=titanic['fare']
lm =sns.lmplot(x = 'age',y = 'fare',data=temp,height=8)
ax = lm.axes
ax[0,0].set_ylim(0,300)
# Out:
# (0, 300)

# %% [markdown]
# #### 3. Add two more parameters, pclass and survived to the plot created in Qn 2.

# %%
temp['pclass'] = titanic['pclass']
temp['survived'] = titanic['survived']
lm =sns.lmplot(x = 'age',y = 'fare',hue='pclass',col='survived',data = temp,height=6)
ax = lm.axes
ax[0,0].set_ylim(-50,300)
# Out:
# (-50, 300)

# %% [markdown]
# #### 4. Visualize the distribution of three classes using countplot. How many first, second and third class passengers were on board. Use sex column as additional parameter using hue.

# %%
lm = sns.countplot(x="class", data=titanic,hue='sex')

# %% [markdown]
# #### 5. Create distplot of age, break-down the plot on categories survived and class using facetgrid.

# %%
g = sns.FacetGrid(titanic, col="survived",  row="class",height=5)
g.map(plt.hist,'age')
